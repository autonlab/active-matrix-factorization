# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from plot_results import *
from plot_results import main as plt_res
from mn_active_pmf import *

# %%
plt_rmse = lambda d: plot_rmses(d, d.keys())
plt_pred_auc = lambda d: plot_pred_aucs(d, d.keys())
plt_ge_cutoff = lambda d, c: plot_num_ge_cutoff(d, c, d.keys())

# %%
_results = {}
def load(name, run):
    if (run, name) not in _results:
        _results[run, name] = load_results('./results/movielens-58k-newmovies-10%-10d/run{}/results_{}.pkl'.format(run, name))
    return _results[run, name]

# %%
stan_newitems = 'stan_newitems_nolookahead_s200w100_200steps'

# %%
plt_rmse(load(stan_newitems, 0))

# %%
plt_ge_cutoff(load(stan_newitems, 0), 3.5)
